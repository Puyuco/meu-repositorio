# %% [markdown]
# # Sobre o conjunto de dados
# "Unicórnio" é um termo usado na indústria de capital de risco para descrever uma startup de capital fechado com valor superior a US$ 1 bilhão. O termo foi popularizado pela primeira vez pela capitalista de risco Aileen Lee, fundadora da Cowboy Ventures, um fundo de capital de risco com sede em Palo Alto, Califórnia.
#
# Unicórnios também podem se referir a um fenômeno de recrutamento no setor de recursos humanos (RH). Os gerentes de RH podem ter grandes expectativas para preencher um cargo, levando-os a procurar candidatos com qualificações superiores às exigidas para um cargo específico. Em essência, esses gerentes estão procurando um unicórnio, o que leva a uma desconexão entre seu candidato ideal e quem eles podem contratar do grupo de pessoas disponíveis.
#
# Download da base de dados:https://www.kaggle.com/datasets/ramjasmaurya/unicorn-startups

# %% [markdown]
# #  Passo 1: Importando as Bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Passo 2: Importando os Dados

# %%
Base_Dados = pd.read_csv('unicorns till sep 2022.csv')

# %% [markdown]
# # Passo 3: Leitura dos Primeiros Registros.

# %%
Base_Dados.head()
# Out:
#      Empresa Valor ($) Data de Adesão           País          City   \
# 0  ByteDance      $140       4/7/2017          China        Beijing
# 1     SpaceX      $127      12/1/2012  United States      Hawthorne
# 2      SHEIN      $100       7/3/2018          China       Shenzhen
# 3     Stripe       $95      1/23/2014  United States  San Francisco
# 4      Canva       $40       1/8/2018      Australia    Surry Hills
#
#                              Setor  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                         Investidores
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
# Verficicação das colunas.

Base_Dados.columns
# Out:
# Index(['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City ',
#        'Industry', 'Investors'],
#       dtype='object')

# %% [markdown]
# # Passo 4: Renomeando os Dados

# %%
Base_Dados.rename(
columns={
    'Company' : 'Empresa',
    'Valuation ($B)' : 'Valor ($)',
    'Date Joined' : 'Data de Adesão',
    'Country' : 'País',
    'City': 'Cidade',
    'Industry' : 'Setor',
    'Investors' : 'Investidores',
}, inplace = True)

# %% [markdown]
# # Passo 5: Verificando os tipos de Informação
#
# OBS:Nessa situação,percebemos que que a Coluna ' Valor ($)' e 'Data de Adesão' está no formato 'object',então teremos que fazer a mudança nos próximos passos para que podemos Manipular e conseguir extraír o máximo de informaçõoes necessárias.Outro ponto importante é que temos alguns campos nulo,significa que teremos que tratar os dados para melhorar o nosso resultado.

# %%
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Empresa         1186 non-null   object
#  1   Valor ($)       1186 non-null   object
#  2   Data de Adesão  1186 non-null   object
#  3   País            1186 non-null   object
#  4   City            1186 non-null   object
#  5   Setor           1186 non-null   object
#  6   Investidores    1168 non-null   object
# dtypes: object(7)
# memory usage: 65.0+ KB

# %% [markdown]
# # Passo 6: Verificando os Campos Nulos
#
# Percebemos que temos 18 campos nulos na coluna 'Investidores',agora que encontramos os campos,agora iremos tratar essa coluna.

# %%
Base_Dados.isnull().sum()
# Out:
# Empresa            0
# Valor ($)          0
# Data de Adesão     0
# País               0
# City               0
# Setor              0
# Investidores      18
# dtype: int64

# %%
plt.figure(figsize = (8,3))
plt.title('Analisando Dados Nulos')
sns.heatmap(Base_Dados.isnull(), cbar = False);

# %% [markdown]
# # Passo 7: Verificando os Campos Únicos

# %%
# Verificando o Campo Inteiro.

Base_Dados.nunique()
# Out:
# Empresa           1183
# Valor ($)          222
# Data de Adesão     695
# País                48
# City               286
# Setor               34
# Investidores      1152
# dtype: int64

# %%
# Verificando a Coluna 'Setor' por Ranking.

Base_Dados['Setor'].value_counts()
# Out:
# Fintech                                                               239
# Internet software & services                                          224
# E-commerce & direct-to-consumer                                       103
# Health                                                                 94
# Artificial intelligence                                                74
# Supply chain, logistics, & delivery                                    65
# Other                                                                  65
# Cybersecurity                                                          58
# Data management & analytics                                            45
# Auto & transportation                                                  40
# Hardware                                                               38
# Mobile & telecommunications                                            37
# Edtech                                                                 32
# ...

# %%
# Verificando a Coluna 'Setor' por Ranking(em porcentagem).

Base_Dados['Setor'].value_counts(normalize = True)
# Out:
# Fintech                                                               0.201518
# Internet software & services                                          0.188870
# E-commerce & direct-to-consumer                                       0.086847
# Health                                                                0.079258
# Artificial intelligence                                               0.062395
# Supply chain, logistics, & delivery                                   0.054806
# Other                                                                 0.054806
# Cybersecurity                                                         0.048904
# Data management & analytics                                           0.037943
# Auto & transportation                                                 0.033727
# Hardware                                                              0.032040
# Mobile & telecommunications                                           0.031197
# ...

# %% [markdown]
# # Gráfico de Setores:

# %%
plt.figure(figsize = (15, 6))
plt.xticks(rotation = 45,ha ='right')
plt.title('Analisando os Setores', size = 20)
plt.bar(Base_Dados['Setor'].value_counts().index,Base_Dados['Setor'].value_counts() );

# %% [markdown]
# # Gráfico de Países:

# %%
plt.figure(figsize = (15, 6))
plt.xticks(rotation = 45,ha ='right')
plt.title('Analisando os Países', size = 20)
plt.bar(Base_Dados['País'].value_counts().index,Base_Dados['País'].value_counts() );

# %%
 # Criando uma variável pra coluna 'País'
    
Analise = round(Base_Dados['País'].value_counts(normalize = True) * 100,1)

# %% [markdown]
# # Gráfico de Pizza em Países:

# %%
# Plot Geral dos Países

plt.title('Análise dos Países Geradores de Unicórnios - Top 10')
plt.pie(
    Analise.head(10),
    labels = Analise.index[0:10],
    shadow = True,
    startangle = 90,
    autopct = '%1.1f%%'
);

# %%
Analise.head(10)
# Out:
# United States     53.6
# China             14.7
# India              5.9
# United Kingdom     3.9
# Germany            2.4
# France             2.0
# Israel             1.9
# Canada             1.6
# Brazil             1.4
# South Korea        1.4
# Name: País, dtype: float64

# %%
Analise.index[0:11]
# Out:
# Index(['United States', 'China', 'India', 'United Kingdom', 'Germany',
#        'France', 'Israel', 'Canada', 'Brazil', 'South Korea', 'Singapore'],
#       dtype='object')

# %% [markdown]
# # Passo 8: Conversão da Colunas

# %%
# Convertendo a Coluna 'Data de Adesão' de 'object' para o formato 'Datetime'

Base_Dados['Data de Adesão'] = pd.to_datetime(Base_Dados['Data de Adesão'] )

# %%
# Convertendo a Coluna 'Valor ($)' de 'object' para o formato 'Float'

Base_Dados['Valor ($)'] = pd.to_numeric(Base_Dados['Valor ($)'].apply(lambda Linha: Linha.replace('$','')))

# %%
# Extrair o Ano e Mês

Base_Dados['Mes'] = pd.DatetimeIndex( Base_Dados['Data de Adesão']).month
Base_Dados['Ano'] = pd.DatetimeIndex( Base_Dados['Data de Adesão']).year

Base_Dados.head()
# Out:
#      Empresa  Valor ($) Data de Adesão           País          City   \
# 0  ByteDance      140.0     2017-04-07          China        Beijing
# 1     SpaceX      127.0     2012-12-01  United States      Hawthorne
# 2      SHEIN      100.0     2018-07-03          China       Shenzhen
# 3     Stripe       95.0     2014-01-23  United States  San Francisco
# 4      Canva       40.0     2018-01-08      Australia    Surry Hills
#
#                              Setor  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                         Investidores  Mes   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2  Tiger Global Management, Sequoia Capital China...    7  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# ...

# %% [markdown]
# # Passo 9: Criando uma Tabela Analítica

# %%
Analise_agrupada = Base_Dados.groupby(by = ['País','Ano','Mes'] ).count()['Empresa'].reset_index()
Analise_agrupada
# Out:
#               País   Ano  Mes  Empresa
# 0        Argentina  2021    8        1
# 1        Australia  2018    1        1
# 2        Australia  2019    3        1
# 3        Australia  2021    5        1
# 4        Australia  2021    7        2
# ..             ...   ...  ...      ...
# 436  United States  2022    6       14
# 437  United States  2022    7        4
# 438  United States  2022    8        3
# 439        Vietnam  2021   10        1
# 440        Vietnam  2021   12        1
#
# [441 rows x 4 columns]

# %% [markdown]
# # Filtrando pelas Empresas Brasileiras:

# %%
Analise_agrupada.loc[Analise_agrupada['País'] == 'Brazil']
# Out:
#       País   Ano  Mes  Empresa
# 14  Brazil  2018    7        1
# 15  Brazil  2018   11        1
# 16  Brazil  2019    6        1
# 17  Brazil  2019    9        1
# 18  Brazil  2019   10        1
# 19  Brazil  2019   12        1
# 20  Brazil  2020    1        1
# 21  Brazil  2020   12        2
# 22  Brazil  2021    1        1
# 23  Brazil  2021    8        2
# 24  Brazil  2021    9        1
# 25  Brazil  2021   10        1
# 26  Brazil  2021   12        1
# 27  Brazil  2022    2        1
# 28  Brazil  2022    5        1

# %% [markdown]
# # Filtrando pelas Empresas Americanas:

# %%
Analise_agrupada.loc[Analise_agrupada['País'] == 'United States']
# Out:
#               País   Ano  Mes  Empresa
# 353  United States  2011    4        1
# 354  United States  2012    6        1
# 355  United States  2012   12        2
# 356  United States  2013    2        1
# 357  United States  2013    5        1
# ..             ...   ...  ...      ...
# 434  United States  2022    4       22
# 435  United States  2022    5       14
# 436  United States  2022    6       14
# 437  United States  2022    7        4
# 438  United States  2022    8        3
#
# [86 rows x 4 columns]

# %%
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Empresa         1186 non-null   object
#  1   Valor ($)       1186 non-null   object
#  2   Data de Adesão  1186 non-null   datetime64[ns]
#  3   País            1186 non-null   object
#  4   City            1186 non-null   object
#  5   Setor           1186 non-null   object
#  6   Investidores    1168 non-null   object
#  7   Mes             1186 non-null   int64
#  8   Ano             1186 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 83.5+ KB

# %% [markdown]
# # Relembrando da conversão da coluna 'Valor ($)'

# %%
# Convertendo a Coluna 'Valor ($)' de 'object' para o formato 'Float'

#pd.to_numeric(Base_Dados['Valor ($)'].apply(lambda Linha: Linha.replace('$','')))

# %%
Base_Dados.head()
# Out:
#      Empresa  Valor ($) Data de Adesão           País          City   \
# 0  ByteDance      140.0     2017-04-07          China        Beijing
# 1     SpaceX      127.0     2012-12-01  United States      Hawthorne
# 2      SHEIN      100.0     2018-07-03          China       Shenzhen
# 3     Stripe       95.0     2014-01-23  United States  San Francisco
# 4      Canva       40.0     2018-01-08      Australia    Surry Hills
#
#                              Setor  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                         Investidores  Mes   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2  Tiger Global Management, Sequoia Capital China...    7  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# ...

# %% [markdown]
# # Análise de Países mais Valiosos

# %%
Analise_Pais = Base_Dados.groupby(by = ['País']).sum()['Valor ($)'].reset_index().sort_values('Valor ($)',ascending = False)
display(Analise_Pais)
# Out:
#                     País  Valor ($)
# 46         United States    2069.89
# 9                  China     678.59
# 45        United Kingdom     205.45
# 20                 India     202.92
# 18               Germany      80.88
# 17                France      58.42
# 1              Australia      54.40
# 7                 Canada      49.23
# 23                Israel      48.02
# 6                 Brazil      40.08
# 38           South Korea      34.13
# 3                Bahamas      32.00
# 21             Indonesia      29.13
# 40                Sweden      23.62
# 30           Netherlands      22.46
# 36             Singapore      20.75
# 19             Hong Kong      20.35
# 29                Mexico      18.70
# 43                Turkey      15.77
# 16               Finland      12.46
# 41           Switzerland      12.30
# 22               Ireland      10.05
# 35            Seychelles      10.00
# 15               Estonia       9.90
# 4                Belgium       8.95
# ...

# %%
Analise_valor = Analise_Pais.sort_values('Valor ($)',ascending = False)
Analise_valor.head(10)
# Out:
#               País  Valor ($)
# 46   United States    2069.89
# 9            China     678.59
# 45  United Kingdom     205.45
# 20           India     202.92
# 18         Germany      80.88
# 17          France      58.42
# 1        Australia      54.40
# 7           Canada      49.23
# 23          Israel      48.02
# 6           Brazil      40.08

# %% [markdown]
# # Análise de Países mais Valiosos por Gráfico

# %%
plt.figure(figsize = (15,6))
plt.plot(Analise_valor['País'],Analise_valor['Valor ($)'])
plt.xticks(rotation = 45, ha = 'right');

# %% [markdown]
# # Relatório Final:
#
#  #  TOP 10 - Maior Setor de Empresas Unicórnios:
#
#     1°  - Fintech(Tecnologia Financeira)
#     2°  - Internet Serviços & Software
#     3°  - E-commerce & D2C(direct-to-consumer)
#     4°  - Saúde
#     5°  - Inteligência Artificial
#     6°  - Cadeia de Suprimentos,Logística & Entrega
#     7°  - Outros
#     8°  - Cibersegurança(Cybersecurity)
#     9°  - Gerenciamento de Dados & Análises
#     10° - Transporte e Automóveis
#
#
#
#  # TOP 10 - Países com maior criação de Empresas Unicórnios:
#
#     1°  - Estados Unidos : 636
#     2°  - China : 174
#     3°  - Índia : 70
#     4°  - Reino Unido : 46
#     5°  - Alemanha : 29
#     6°  - França : 24
#     7°  - Israel : 22
#     8°  - Canadá : 19
#     9°  - Brasil : 17
#     10° - Coréia do Sul : 17
#
#
#
#  # TOP - Países com maiores Valores de Empresas Unicórnios:
#
#     1°  - Estados Unidos : 2069.89 BI $
# 2°  - China : 678.59 BI $
#     3°  - Reino Unido : 205.45 BI $
# 4°  - Índia : 202.92 BI $
#     5°  - Alemanha : 80.88 BI $
# 6°  - França : 58.42 BI $
#     7°  - Austrália : 54.40 $
# 8°  - Canadá : 49.23 BI $
#     9°  - Israel : 28.02 BI $
# 10° - Brasil : 40.08 BI $
